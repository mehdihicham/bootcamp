# %%
import numpy as np
import pandas as pd

# %%
# !head data/gfmt_sleep.csv
# Out:
# ﻿participant number,gender,age,correct hit percentage,correct reject percentage,percent correct,confidence when correct hit,confidence when incorrect hit,confidence when correct reject,confidence when incorrect reject,confidence when correct,confidence when incorrect,sci,psqi,ess
# 8,f,39,65,80,72.5,91,90,93,83.5,93,90,9,13,2
# 16,m,42,90,90,90,75.5,55.5,70.5,50,75,50,4,11,7
# 18,f,31,90,95,92.5,89.5,90,86,81,89,88,10,9,3
# 22,f,35,100,75,87.5,89.5,*,71,80,88,80,13,8,20
# 27,f,74,60,65,62.5,68.5,49,61,49,65,49,13,9,12
# 28,f,61,80,20,50,71,63,31,72.5,64.5,70.5,15,14,2
# 30,m,32,90,75,82.5,67,56.5,66,65,66,64,16,9,3
# 33,m,62,45,90,67.5,54,37,65,81.5,62,61,14,9,9
# 34,f,33,80,100,90,70.5,76.5,64.5,*,68,76.5,14,12,10

# %%
df = pd.read_csv('data/gfmt_sleep.csv',na_values = '*')
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    participant number gender  age  correct hit percentage  \
# 0                   8      f   39                      65
# 1                  16      m   42                      90
# 2                  18      f   31                      90
# 3                  22      f   35                     100
# 4                  27      f   74                      60
#
#    correct reject percentage  percent correct  confidence when correct hit  \
# 0                         80             72.5                         91.0
# 1                         90             90.0                         75.5
# 2                         95             92.5                         89.5
# 3                         75             87.5                         89.5
# 4                         65             62.5                         68.5
#
#    confidence when incorrect hit  confidence when correct reject  \
# 0                           90.0                            93.0
# ...

# %%
df['percent correct']
# Out:
# 0      72.5
# 1      90.0
# 2      92.5
# 3      87.5
# 4      62.5
#        ...
# 97     77.5
# 98     87.5
# 99     75.0
# 100    70.0
# 101    62.5
# Name: percent correct, Length: 102, dtype: float64

# %%
df['percent correct'][0]
# Out:
# 72.5

# %%
df.loc[4,'percent correct']
# Out:
# 62.5

# %%
df.loc[df['participant number']==42]
# Out:
#     participant number gender  age  correct hit percentage  \
# 54                  42      m   29                     100
#
#     correct reject percentage  percent correct  confidence when correct hit  \
# 54                         70             85.0                         75.0
#
#     confidence when incorrect hit  confidence when correct reject  \
# 54                            NaN                            64.5
#
#     confidence when incorrect reject  confidence when correct  \
# 54                              43.0                     74.0
#
#     confidence when incorrect  sci  psqi  ess
# 54                       43.0   32     1    6

# %%
df.loc[df['participant number']==22,'percent correct']
# Out:
# 3    87.5
# Name: percent correct, dtype: float64

# %%
df['gender']=='f'
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 97      True
# 98      True
# 99      True
# 100     True
# 101     True
# Name: gender, Length: 102, dtype: bool

# %%
df.loc[df['gender'] == 'f',['percent correct','age']]
# Out:
#      percent correct  age
# 0               72.5   39
# 2               92.5   31
# 3               87.5   35
# 4               62.5   74
# 5               50.0   61
# ..               ...  ...
# 97              77.5   23
# 98              87.5   70
# 99              75.0   24
# 100             70.0   40
# 101             62.5   33
#
# [74 rows x 2 columns]

# %%
df.loc[df['age']> 65,:]
# Out:
#     participant number gender  age  correct hit percentage  \
# 4                   27      f   74                      60
# 67                  59      f   67                      95
# 72                  64      f   69                      95
# 80                  73      f   74                      85
# 91                  88      m   66                      60
# 98                  98      f   70                      90
#
#     correct reject percentage  percent correct  confidence when correct hit  \
# 4                          65             62.5                         68.5
# 67                         75             85.0                         70.0
# 72                         80             87.5                         80.0
# 80                         80             82.5                         66.0
# 91                         85             72.5                         67.5
# 98                         85             87.5                         65.5
#
# ...

# %%
df.loc[df['age']> 65]
# Out:
#     participant number gender  age  correct hit percentage  \
# 4                   27      f   74                      60
# 67                  59      f   67                      95
# 72                  64      f   69                      95
# 80                  73      f   74                      85
# 91                  88      m   66                      60
# 98                  98      f   70                      90
#
#     correct reject percentage  percent correct  confidence when correct hit  \
# 4                          65             62.5                         68.5
# 67                         75             85.0                         70.0
# 72                         80             87.5                         80.0
# 80                         80             82.5                         66.0
# 91                         85             72.5                         67.5
# 98                         85             87.5                         65.5
#
# ...

# %%
df.loc[(df['age']>65) & (df['gender']=='m'),:] # & is the bitwise and comparison
# Out:
#     participant number gender  age  correct hit percentage  \
# 91                  88      m   66                      60
#
#     correct reject percentage  percent correct  confidence when correct hit  \
# 91                         85             72.5                         67.5
#
#     confidence when incorrect hit  confidence when correct reject  \
# 91                           66.0                            74.0
#
#     confidence when incorrect reject  confidence when correct  \
# 91                              57.0                     74.0
#
#     confidence when incorrect  sci  psqi  ess
# 91                       64.0   30     5    9

# %%
df['insomnia'] = df['sci'] <=16

# %%
df.head()
# Out:
#    participant number gender  age  correct hit percentage  \
# 0                   8      f   39                      65
# 1                  16      m   42                      90
# 2                  18      f   31                      90
# 3                  22      f   35                     100
# 4                  27      f   74                      60
#
#    correct reject percentage  percent correct  confidence when correct hit  \
# 0                         80             72.5                         91.0
# 1                         90             90.0                         75.5
# 2                         95             92.5                         89.5
# 3                         75             87.5                         89.5
# 4                         65             62.5                         68.5
#
#    confidence when incorrect hit  confidence when correct reject  \
# 0                           90.0                            93.0
# ...

# %%
np.mean(df['age'])
# Out:
# 37.92156862745098

# %%
df.describe()
df.describe().loc['50%', :]
# Out:
# participant number                  52.50
# age                                 36.50
# correct hit percentage              90.00
# correct reject percentage           80.00
# percent correct                     83.75
# confidence when correct hit         75.00
# confidence when incorrect hit       56.25
# confidence when correct reject      71.25
# confidence when incorrect reject    61.00
# confidence when correct             75.75
# confidence when incorrect           61.50
# sci                                 23.50
# psqi                                 5.00
# ess                                  7.00
# Name: 50%, dtype: float64

# %%
print('Insomniacs:', np.mean(df.loc[df['insomnia'], 'percent correct']))
print('Control:   ', np.mean(df.loc[~df['insomnia'], 'percent correct']))
# Out:
# Insomniacs: 76.1
# Control:    81.46103896103897

# %%
df1 = df.loc[df['insomnia']]
df1.to_csv('gfmt_sleep_with_insomnia.csv', index=False)

# %%
grouped = df.groupby('insomnia')

# Take a look
grouped.mean()
# Out:
#           participant number        age  correct hit percentage  \
# insomnia
# False               51.61039  37.142857               83.441558
# True                53.40000  40.320000               82.000000
#
#           correct reject percentage  percent correct  \
# insomnia
# False                     79.480519        81.461039
# True                      70.200000        76.100000
#
#           confidence when correct hit  confidence when incorrect hit  \
# insomnia
# False                       73.902597                      56.238806
# True                        78.340000                      67.735294
#
#           confidence when correct reject  confidence when incorrect reject  \
# insomnia
# False                          70.603896                         58.443662
# True                           72.780000                         70.181818
#
#           confidence when correct  confidence when incorrect        sci  \
# insomnia
# ...

# %%
grouped['percent correct'].mean()
# Out:
# insomnia
# False    81.461039
# True     76.100000
# Name: percent correct, dtype: float64

# %%
grouped['percent correct'].mean().reset_index()
# Out:
#    insomnia  percent correct
# 0     False        81.461039
# 1      True        76.100000

# %%
df.groupby(['gender', 'insomnia']).median().reset_index()
# Out:
#   gender  insomnia  participant number   age  correct hit percentage  \
# 0      f     False                58.0  36.0                    85.0
# 1      f      True                46.0  39.0                    80.0
# 2      m     False                41.0  38.5                    90.0
# 3      m      True                55.5  37.0                    95.0
#
#    correct reject percentage  percent correct  confidence when correct hit  \
# 0                       80.0            85.00                        74.00
# 1                       75.0            72.50                        76.50
# 2                       80.0            82.50                        76.00
# 3                       82.5            83.75                        83.75
#
#    confidence when incorrect hit  confidence when correct reject  \
# 0                          55.00                           70.50
# 1                          73.75                           71.00
# ...

# %%
def coeff_of_var(data):
    """Compute coefficient of variation from an array of data."""
    return np.std(data) / np.mean(data)
df.groupby('insomnia').agg(coeff_of_var).reset_index()
# Out:
#    insomnia  participant number       age  correct hit percentage  \
# 0     False            0.586191  0.384262                0.166784
# 1      True            0.536117  0.313853                0.218834
#
#    correct reject percentage  percent correct  confidence when correct hit  \
# 0                   0.184061         0.138785                     0.195978
# 1                   0.325760         0.171856                     0.156219
#
#    confidence when incorrect hit  confidence when correct reject  \
# 0                       0.350286                        0.204312
# 1                       0.225440                        0.222827
#
#    confidence when incorrect reject  confidence when correct  \
# 0                          0.298216                 0.187304
# 1                          0.211512                 0.160061
#
#    confidence when incorrect       sci      psqi       ess
# 0                   0.262509  0.175245  0.577869  0.571566
# ...

# %%
for name,group in df.groupby(['gender','insomnia']):
    print(name,':',group['percent correct'].mean())
# Out:
# ('f', False) : 82.04545454545455
# ('f', True) : 73.94736842105263
# ('m', False) : 80.0
# ('m', True) : 82.91666666666667

# %% [markdown]
# ### how to tidy

# %%
df = pd.read_csv('data/reeves_gradient_width_various_methods.csv',comment = '#'
                ,header = [0,1])
df.head()
# Out:
#            wt                dl1/+; dl-venus/+                          \
#   wholemounts cross-sections       anti-Dorsal anti-Venus Venus (live)
# 0      0.1288         0.1327            0.1482     0.1632       0.1666
# 1      0.1554         0.1457            0.1503     0.1671       0.1753
# 2      0.1306         0.1447            0.1577     0.1704       0.1705
# 3      0.1413         0.1282            0.1711     0.1779          NaN
# 4      0.1557         0.1487            0.1342     0.1483          NaN
#
#   dl1/+; dl-gfp/+
#       anti-Dorsal anti-GFP GFP (live)
# 0          0.2248   0.2389     0.2412
# 1          0.1891   0.2035     0.1942
# 2          0.1705   0.1943     0.2186
# 3          0.1735   0.2000     0.2104
# 4          0.2135   0.2560     0.2463

# %%
df_tidy = pd.melt(df, value_name="gradient width", var_name=["genotype", "method"])
df_tidy
# Out:
#              genotype       method  gradient width
# 0                  wt  wholemounts          0.1288
# 1                  wt  wholemounts          0.1554
# 2                  wt  wholemounts          0.1306
# 3                  wt  wholemounts          0.1413
# 4                  wt  wholemounts          0.1557
# ...               ...          ...             ...
# 1211  dl1/+; dl-gfp/+   GFP (live)             NaN
# 1212  dl1/+; dl-gfp/+   GFP (live)             NaN
# 1213  dl1/+; dl-gfp/+   GFP (live)             NaN
# 1214  dl1/+; dl-gfp/+   GFP (live)             NaN
# 1215  dl1/+; dl-gfp/+   GFP (live)             NaN
#
# [1216 rows x 3 columns]

# %%
df_tidy = df_tidy.dropna()

# %%
df_tidy.head()
# Out:
#   genotype       method  gradient width
# 0       wt  wholemounts          0.1288
# 1       wt  wholemounts          0.1554
# 2       wt  wholemounts          0.1306
# 3       wt  wholemounts          0.1413
# 4       wt  wholemounts          0.1557
